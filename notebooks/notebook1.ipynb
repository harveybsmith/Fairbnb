# %%
import pymongo
import pandas as pd
from pymongo import MongoClient

# %%
# !python -m pip install pymongo[tls]

# %%
client = MongoClient()

#point the client at mongo URI
client = MongoClient('mongodb+srv://mixtek:Octopus1985!@cluster0-ko8qf.mongodb.net/test?retryWrites=true&w=majority')
#select database
db = client['sample_airbnb']
#select the collection within the database
test = db.listingsAndReviews
#convert entire collection to Pandas dataframe
this = pd.DataFrame(list(test.find()))

# %%
this.shape
# Out:
# (5555, 42)

# %%
# !pip install dnspython

# %%
client = pymongo.MongoClient('mongodb+srv://mixtek:Octopus1985!@cluster0-ko8qf.mongodb.net/test?retryWrites=true&w=majority')

# %%
# !pip install pymongo[tls]

# %%
# !python -c "import ssl; print(getattr(ssl, 'HAS_SNI', False))"
# Out:
# True

# %%
db = client['sample_airbnb']

# %%
airbnb = db.listingsAndReviews

# %%
#convert entire collection to Pandas dataframe
this = pd.DataFrame(list(airbnb.find()))

# %%
this
# Out:
#            _id                                             access  \
# 0      1001265                           Pool, hot tub and tennis
# 1     10009999
# 2     10059244              Vous avez accès à tout l'appartement.
# 3     10051164  O hóspedes poderão acessar espaços compartilha...
# 4     10083468             My guests have acess to all apartment.
# 5     10038496                                     todo o espaço.
# 6     10069642
# 7     10082422                         Ideal couple or 2 friends.
# 8     10066928  Le logement sera disponible en entier pour vot...
# 9     10006546  We are always available to help guests. The ho...
# 10    10047964
# 11    10021707
# 12     1003530                                     New York City!
# 13    10057826  Guest will have access to common terraces, lou...
# 14    10030955
# 15    10059872
# 16    10057447
# 17    10082307
# 18    10109896  You'll access all areas except the master bedr...
# 19    10116578
# ...
