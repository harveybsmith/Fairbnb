# %%
import pandas as pd

# %%
import numpy as np

# %%
import re
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\Ben\Documents\Fairbnb\data\data.csv")

# %% [markdown]
# # Explore Data

# %%
data.head()
# Out:
#    Unnamed: 0       _id                                             access  \
# 0           0   1003530                                     New York City!
# 1           1   1001265                           Pool, hot tub and tennis
# 2           2  10051164  O hóspedes poderão acessar espaços compartilha...
# 3           3  10009999                                                NaN
# 4           4  10038496                                     todo o espaço.
#
#    accommodates                                            address  \
# 0             2  {'street': 'New York, NY, United States', 'sub...
# 1             2  {'street': 'Honolulu, HI, United States', 'sub...
# 2             8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3             4  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4             4  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
#
#                                            amenities  \
# 0  ['Internet', 'Wifi', 'Air conditioning', 'Kitc...
# 1  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 2  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 3  ['Wifi', 'Wheelchair accessible', 'Kitchen', '...
# 4  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
#
#                                         availability  bathrooms  bed_type  \
# 0  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 1  {'availability_30': 16, 'availability_60': 46,...        1.0  Real Bed
# 2  {'availability_30': 10, 'availability_60': 10,...        4.0  Real Bed
# 3  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 4  {'availability_30': 7, 'availability_60': 19, ...        2.0  Real Bed
#
#    bedrooms  ...  property_type  \
# 0       1.0  ...      Apartment
# 1       1.0  ...    Condominium
# 2       1.0  ...          House
# 3       1.0  ...      Apartment
# 4       1.0  ...      Apartment
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 10, 'review_scores_...
# 1  {'review_scores_accuracy': 9, 'review_scores_c...
# 2  {'review_scores_accuracy': 10, 'review_scores_...
# 3                                                 {}
# 4  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                              reviews  reviews_per_month  \
# 0  [{'_id': '4351675', 'date': datetime.datetime(...                NaN
# 1  [{'_id': '4765259', 'date': datetime.datetime(...                NaN
# 2  [{'_id': '61992538', 'date': datetime.datetime...                NaN
# 3                                                 []                NaN
# 4  [{'_id': '60037020', 'date': datetime.datetime...                NaN
#
#          room_type  security_deposit  \
# 0     Private room               0.0
# 1  Entire home/apt               NaN
# 2     Private room               0.0
# 3  Entire home/apt               NaN
# 4  Entire home/apt             600.0
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
# 1  Great studio located on Ala Moana across the s...
# 2  Este quarto está preparado para acomodar confo...
# 3  Lovely one bedroom + sofa-bed in the living ro...
# 4  The apartment has a living room, wash room, su...
#
#                                              summary  \
# 0                                                NaN
# 1  A short distance from Honolulu's billion dolla...
# 2  Old floor, intirely reformed, destined to rece...
# 3  One bedroom + sofa-bed in quiet and bucolic ne...
# 4  The Apartment has a living room, toilet, bedro...
#
#                                              transit weekly_price
# 0  Conveniently located near 1, 2, 3, B & C subwa...          NaN
# 1  Honolulu does have a very good air conditioned...        650.0
# 2  Perto do metrô e várias linhas de ônibus. Aces...          NaN
# 3  Easy access to transport (bus, taxi, car) and ...       1492.0
# 4  On the street there is plenty of transport and...          NaN
#
# [5 rows x 43 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 43 columns):
# Unnamed: 0               5555 non-null int64
# _id                      5555 non-null int64
# access                   3102 non-null object
# accommodates             5555 non-null int64
# address                  5555 non-null object
# amenities                5555 non-null object
# availability             5555 non-null object
# bathrooms                5545 non-null float64
# bed_type                 5555 non-null object
# bedrooms                 5550 non-null float64
# beds                     5542 non-null float64
# calendar_last_scraped    5555 non-null object
# cancellation_policy      5555 non-null object
# cleaning_fee             4024 non-null float64
# description              5460 non-null object
# extra_people             5555 non-null float64
# first_review             4167 non-null object
# guests_included          5555 non-null int64
# host                     5555 non-null object
# house_rules              3270 non-null object
# images                   5555 non-null object
# interaction              3077 non-null object
# last_review              4167 non-null object
# last_scraped             5555 non-null object
# listing_url              5555 non-null object
# maximum_nights           5555 non-null int64
# minimum_nights           5555 non-null int64
# monthly_price            656 non-null float64
# name                     5547 non-null object
# neighborhood_overview    3314 non-null object
# notes                    2474 non-null object
# number_of_reviews        5555 non-null int64
# price                    5555 non-null float64
# property_type            5555 non-null object
# review_scores            5555 non-null object
# reviews                  5555 non-null object
# reviews_per_month        94 non-null float64
# room_type                5555 non-null object
# security_deposit         3471 non-null float64
# space                    3929 non-null object
# summary                  5297 non-null object
# transit                  3323 non-null object
# weekly_price             714 non-null float64
# dtypes: float64(10), int64(7), object(26)
# memory usage: 1.8+ MB

# %% [markdown]
# ### Check outliers and distribution of target variable

# %%
data['price'].hist(bins=100)

# %%
data['price'].describe()
# Out:
# count     5555.000000
# mean       278.766157
# std        842.215531
# min          9.000000
# 25%         70.000000
# 50%        129.000000
# 75%        280.000000
# max      48842.000000
# Name: price, dtype: float64

# %%
data[data['price']==48842]
# Out:
#       Unnamed: 0       _id access  accommodates  \
# 1982        1982  20275354    NaN             1
#
#                                                 address  \
# 1982  {'street': 'Şişli, İstanbul, Turkey', 'suburb'...
#
#                                               amenities  \
# 1982  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Smoking...
#
#                                            availability  bathrooms  bed_type  \
# 1982  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
#
#       bedrooms  ...  property_type review_scores reviews  reviews_per_month  \
# 1982       1.0  ...      Apartment            {}      []                NaN
#
#          room_type  security_deposit  \
# 1982  Private room               NaN
#
#                                                   space  \
# 1982  our flat which is located in Sisli Bomonti jus...
#
#                                                 summary transit weekly_price
# 1982  We are new married couple.We have have one ful...     NaN          NaN
#
# [1 rows x 43 columns]

# %%
# drop this row
i = data[data['price']==48842].index
data.drop(i, inplace=True)

# %%
data['price'].hist(bins=50)

# %% [markdown]
# Still another outlier. Lets see why

# %%
data['price'].describe()
# Out:
# count     5554.000000
# mean       270.022326
# std        533.547676
# min          9.000000
# 25%         70.000000
# 50%        129.000000
# 75%        280.000000
# max      11681.000000
# Name: price, dtype: float64

# %%
data[data['price']==11681].loc[863]['reviews']
# Out:
# "[{'_id': '96539746', 'date': datetime.datetime(2016, 8, 23, 4, 0), 'listing_id': '14644562', 'reviewer_id': '91413032', 'reviewer_name': 'Cheuk Wai', 'comments': 'The host canceled this reservation 6 days before arrival. This is an automated posting.'}]"

# %% [markdown]
# We can see from the reivew for this listing that is was an automated span posting so eliminate it

# %%
data[data['price']==11681].loc[3369]['reviews']
# Out:
# "[{'_id': '308703954', 'date': datetime.datetime(2018, 8, 17, 4, 0), 'listing_id': '27593455', 'reviewer_id': '48471824', 'reviewer_name': 'Lin', 'comments': '地理位置优越,往返机场A21,门到门'}, {'_id': '312647218', 'date': datetime.datetime(2018, 8, 24, 4, 0), 'listing_id': '27593455', 'reviewer_id': '85301073', 'reviewer_name': '妍', 'comments': '隔音差,隔壁打电话吵了一夜,房间有小虫子,不是蚊子,被咬了,潮湿,被褥有点不干净,地理位置倒是挺好的,价格不算性价比最高的'}, {'_id': '313120777', 'date': datetime.datetime(2018, 8, 25, 4, 0), 'listing_id': '27593455', 'reviewer_id': '143569984', 'reviewer_name': '效康', 'comments': '挺不错的'}, {'_id': '330735980', 'date': datetime.datetime(2018, 10, 1, 4, 0), 'listing_id': '27593455', 'reviewer_id': '55813414', 'reviewer_name': 'Jeffrey', 'comments': 'Good cheap place in Mong Kok. Everything was clean, but there was an odour coming from the bathroom'}, {'_id': '365999651', 'date': datetime.datetime(2019, 1, 2, 5, 0), 'listing_id': '27593455', 'reviewer_id': '60607093', 'reviewer_name': 'Adele', 'comments': 'Simple and budget stay.'}]"

# %% [markdown]
# We can see from the review in English that is was a 'Good and cheap place' so this pricing is obviously an error. Delete it too

# %%
i = data[data['price']==11681].index
data.drop(i, inplace=True)

# %%
data['price'].hist(bins=50)

# %% [markdown]
# Filter for less than 4000$ price

# %%
data = data[data['price'] < 4000]

# %% [markdown]
# Lets check the distribution again

# %%
data['price'].hist(bins=50)

# %%
data['price'].describe()
# Out:
# count    5538.000000
# mean      250.147346
# std       357.000997
# min         9.000000
# 25%        70.000000
# 50%       129.000000
# 75%       280.000000
# max      3730.000000
# Name: price, dtype: float64

# %%
data[data['price']==3730]
# Out:
#       Unnamed: 0      _id                                             access  \
# 2369        2369  2301710  TV a cabo (sky), wifi, cozinha completa, cama ...
#
#       accommodates                                            address  \
# 2369             8  {'street': 'Rio, Rio de Janeiro, Brazil', 'sub...
#
#                                               amenities  \
# 2369  ['Cable TV', 'Air conditioning', 'Kitchen', 'P...
#
#                                            availability  bathrooms  bed_type  \
# 2369  {'availability_30': 25, 'availability_60': 55,...        2.5  Real Bed
#
#       bedrooms  ...  property_type  \
# 2369       4.0  ...          House
#
#                                           review_scores  \
# 2369  {'review_scores_accuracy': 8, 'review_scores_c...
#
#                                                 reviews  reviews_per_month  \
# 2369  [{'_id': '14612042', 'date': datetime.datetime...                NaN
#
#             room_type  security_deposit  \
# 2369  Entire home/apt            1865.0
#
#                                                   space  \
# 2369  Casa na melhor quadra de ipanema, Rio de Janei...
#
#                                                 summary  \
# 2369  Casa com 3 quartos, 1 suite,  salão, lavabo, v...
#
#                                                 transit weekly_price
# 2369  Estação do metrô na Pça N. Sra da Paz na mesma...          NaN
#
# [1 rows x 43 columns]

# %%
data['images'].iloc[2369]
# Out:
# "{'thumbnail_url': '', 'medium_url': '', 'picture_url': 'https://a0.muscache.com/im/pictures/204d9434-7b0c-4180-b41d-e9fc97e6933a.jpg?aki_policy=large', 'xl_picture_url': ''}"

# %% [markdown]
# No way thats 3760 a night.  This must be a monthly rate mistakenly listed in the daily price.  Let delete that one

# %%
i = data[data['price']==3726].index
data.drop(i, inplace=True)

# %%
i = data[data['price']==3730].index
data.drop(i, inplace=True)

# %%
data[data['price']>1000]
# Out:
#       Unnamed: 0       _id                                             access  \
# 100          100  10449328           Acesso livre pela casa. Permitido fumar.
# 103          103  10295352                                                NaN
# 117          117   1066648                                                NaN
# 128          128  10839973                                                NaN
# 132          132  10840938                                                NaN
# 141          141  10893326                                                NaN
# 142          142  10816768  The building has a 24 hour doorman with key-le...
# 281          281   1176693  The entire apartment with all amenities is acc...
# 311          311  11948705  Bed linen, towels, kitchen appliances, kitchen...
# 312          312  11963985                                                NaN
# 347          347  12188649                                                NaN
# 355          355  12104860  Podem ir à praia caminhando em 5 minutos. Terã...
# 377          377   1229847  the rooftop is huge and you can entertain a nu...
# 387          387  12068078                                                NaN
# 396          396  12270044  Acesso irrestrito à sala de tv, academia, saun...
# 408          408  12452082                                                NaN
# 415          415  12591225                                                NaN
# 440          440  12742947  Guest will have access to both bedrooms, the b...
# 471          471  13218264                Tv a cabo, Wi-Fi, máquina de lavar.
# 474          474  12923454                                                NaN
# 481          481  13316078                                                NaN
# 494          494  12814401  Guests can easily access the apartment by Bus,...
# 559          559  13317720                                                NaN
# 579          579  13444131                                                NaN
# 590          590  13397791                                                NaN
# 597          597  13414552                                                NaN
# 638          638  13559998                                                NaN
# 654          654  13505139  You are welcome to use the whole space as your...
# 656          656  13603801  Apartment equipment : 1. Free WIFI 2. Smart TV...
# 743          743  13945645                            Wifi   Hair dryer  Iron
# ...          ...       ...                                                ...
# 4459        4459   3382961  LOFT DE COIN, TRÈS GRAND QUARTIER INTERNATIONA...
# 4506        4506   3410502                                                NaN
# 4575        4575   4241384  -The room has a very comfortable double-bed, a...
# 4592        4592   4374881   TV a cabo, internet, ar condicionado e banheiro.
# 4600        4600   4505019            Gym, swimming pool, sauna, reading room
# 4610        4610   4441805  Between Bağdat Street  and Minübüs street, eas...
# 4629        4629   4667913                            by car,by bus, on foot,
# 4657        4657   4755673  The place that listed have TV, refrigerator, w...
# 4691        4691     48305  Entire private unit, 6 bedrooms and terrace. N...
# 4714        4714   4995138                                                NaN
# 4842        4842   5725151  Provided Free wifi, usb chargers, slippers, to...
# 4877        4877   6265781  Decorated with colourful furniture and paintin...
# 5027        5027   7459725  Os hospedes alem de muito bem acomodados num l...
# 5050        5050    685373  Guests will have full access to the whole apar...
# 5051        5051   6925961                                                NaN
# 5056        5056   7375957  In your room, you will have: * TV * Airconditi...
# 5114        5114   7212218                                                NaN
# 5138        5138   7311170  There's a shared rooftop on the last floor of ...
# 5151        5151   7369437                                                NaN
# 5270        5270   8359801                                                NaN
# 5276        5276   8358372                                                NaN
# 5308        5308   8566106  Caso deseje serviço de limpeza diário, temos c...
# 5367        5367    892349  Linen / towels / Free WiFi / AirCon / living (...
# 5378        5378   8877086  Any special requests can be arranged after con...
# 5389        5389   9138303  In your room, you will have: * TV * Airconditi...
# 5428        5428   9313155  Our entire apartment has 1 shower, bath &toile...
# 5473        5473   9708020                                                NaN
# 5544        5544   9834713                                                NaN
# 5551        5551   9733671                                                NaN
# 5554        5554   9979991                                                NaN
#
#       accommodates                                            address  \
# 100             11  {'street': 'Rio de Janeiro, State of Rio de Ja...
# 103              6  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 117              8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 128              2  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
# 132              5  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 141              2  {'street': 'Sheung Wan, Hong Kong Island, Hong...
# 142              5  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 281              8  {'street': 'Causeway Bay, Hong Kong', 'suburb'...
# 311              6  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 312              8  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 347              8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 355              8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 377              4  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 387              6  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 396              2  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 408              8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 415             10  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 440              5  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 471              6  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 474              2  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 481              6  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 494              6  {'street': 'Hong Kong , Causeway Bay, Hong Kon...
# 559              4  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 579              5  {'street': 'Jacarepagua, Rio de Janeiro, Brazi...
# 590              6  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 597              4  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 638              3  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 654              2  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 656              9  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 743              9  {'street': 'Fatih, İstanbul, Turkey', 'suburb'...
# ...            ...                                                ...
# 4459             6  {'street': 'Montreal, QC, Canada', 'suburb': '...
# 4506            16  {'street': 'Istanbul, Istanbul Province, Turke...
# 4575             3  {'street': 'Beyoğlu, İstanbul, Turkey', 'subur...
# 4592             6  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 4600             4  {'street': 'Hong Kong, Hung Hom Bay, Hong Kong...
# 4610             4  {'street': 'İstanbul- Kadıkoy, İstanbul, Turke...
# 4629             4  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4657             8  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 4691            13  {'street': 'Rio de Janeiro, RJ, Brazil', 'subu...
# 4714             6  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4842             4  {'street': 'Hk, 香港島, Hong Kong', 'suburb': 'Ca...
# 4877             8  {'street': 'İstanbul, İstanbul, Turkey', 'subu...
# 5027            10  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5050             7  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5051             3  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5056             3  {'street': '旺角, 九龍, Hong Kong', 'suburb': 'Yau...
# 5114             4  {'street': 'Fatih, İstanbul, Turkey', 'suburb'...
# 5138             6  {'street': 'Hong Kong, Hong Kong', 'suburb': '...
# 5151            11  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
# 5270             6  {'street': 'Rio de Janeiro, State of Rio de Ja...
# 5276             4  {'street': 'Hong Kong Island, New Territories,...
# 5308             8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5367            16  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5378             3  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5389             2  {'street': 'Mongkok, kowloon, Hong Kong', 'sub...
# 5428             7  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5473            10  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5544             8  {'street': '九龍, 九龍, Hong Kong', 'suburb': 'Mon...
# 5551             8  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5554             3  {'street': 'Hong Kong, Kowloon, Hong Kong', 's...
#
#                                               amenities  \
# 100   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 103   ['Cable TV', 'Wifi', 'Air conditioning', 'Whee...
# 117   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 128   ['TV', 'Wifi', 'Air conditioning', 'Elevator',...
# 132   ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 141   ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 142   ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 281   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 311   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 312   ['Internet', 'Wifi', 'Air conditioning', 'Pool...
# 347   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 355   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 377   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 387   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 396   ['Cable TV', 'Internet', 'Wifi', 'Air conditio...
# 408   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 415   ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 440   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 471   ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...
# 474   ['Smoking allowed', 'Doorman', 'Elevator', 'Bu...
# 481   ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...
# 494   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 559   ['TV', 'Air conditioning', 'Pool', 'Kitchen', ...
# 579   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 590   ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...
# 597   ['Wifi', 'Air conditioning', 'Pool', 'Kitchen'...
# 638   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 654   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 656   ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 743   ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# ...                                                 ...
# 4459  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 4506  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 4575  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...
# 4592  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 4600  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 4610  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 4629  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 4657  ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...
# 4691  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 4714  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 4842  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 4877  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 5027  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...
# 5050  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 5051  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 5056  ['TV', 'Wifi', 'Air conditioning', 'Doorman', ...
# 5114  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 5138  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 5151  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 5270  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 5276  ['TV', 'Internet', 'Wifi', 'Air conditioning',...
# 5308  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 5367  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 5378  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 5389  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...
# 5428  ['TV', 'Cable TV', 'Wifi', 'Air conditioning',...
# 5473  ['Cable TV', 'Wifi', 'Air conditioning', 'Pool...
# 5544  ['TV', 'Wifi', 'Air conditioning', 'Smoking al...
# 5551  ['TV', 'Wifi', 'Air conditioning', 'Kitchen', ...
# 5554  ['TV', 'Internet', 'Air conditioning', 'Kitche...
#
#                                            availability  bathrooms  bed_type  \
# 100   {'availability_30': 30, 'availability_60': 60,...        7.0  Real Bed
# 103   {'availability_30': 0, 'availability_60': 0, '...        3.0  Real Bed
# 117   {'availability_30': 23, 'availability_60': 53,...        5.0  Real Bed
# 128   {'availability_30': 30, 'availability_60': 60,...        1.0  Real Bed
# 132   {'availability_30': 7, 'availability_60': 24, ...        1.5  Real Bed
# 141   {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 142   {'availability_30': 4, 'availability_60': 10, ...        1.0  Real Bed
# 281   {'availability_30': 12, 'availability_60': 29,...        2.0  Real Bed
# 311   {'availability_30': 30, 'availability_60': 60,...        4.0  Real Bed
# 312   {'availability_30': 27, 'availability_60': 57,...        7.0  Real Bed
# 347   {'availability_30': 30, 'availability_60': 60,...        3.0  Real Bed
# 355   {'availability_30': 0, 'availability_60': 0, '...        3.5  Real Bed
# 377   {'availability_30': 0, 'availability_60': 9, '...        1.0  Real Bed
# 387   {'availability_30': 30, 'availability_60': 60,...        2.0  Real Bed
# 396   {'availability_30': 28, 'availability_60': 58,...        1.0  Real Bed
# 408   {'availability_30': 0, 'availability_60': 0, '...        2.5  Real Bed
# 415   {'availability_30': 0, 'availability_60': 0, '...        8.0  Real Bed
# 440   {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 471   {'availability_30': 30, 'availability_60': 60,...        1.0  Real Bed
# 474   {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 481   {'availability_30': 23, 'availability_60': 53,...        3.0  Real Bed
# 494   {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 559   {'availability_30': 29, 'availability_60': 59,...        2.0  Real Bed
# 579   {'availability_30': 0, 'availability_60': 0, '...        2.0  Real Bed
# 590   {'availability_30': 0, 'availability_60': 0, '...        2.0  Real Bed
# 597   {'availability_30': 23, 'availability_60': 53,...        2.0  Real Bed
# 638   {'availability_30': 0, 'availability_60': 0, '...        2.5  Real Bed
# 654   {'availability_30': 5, 'availability_60': 21, ...        1.5  Real Bed
# 656   {'availability_30': 4, 'availability_60': 7, '...        2.0  Real Bed
# 743   {'availability_30': 30, 'availability_60': 60,...        3.0  Real Bed
# ...                                                 ...        ...       ...
# 4459  {'availability_30': 0, 'availability_60': 9, '...        2.0  Real Bed
# 4506  {'availability_30': 30, 'availability_60': 60,...        8.0  Real Bed
# 4575  {'availability_30': 30, 'availability_60': 60,...        1.0  Real Bed
# 4592  {'availability_30': 30, 'availability_60': 60,...        2.0  Real Bed
# 4600  {'availability_30': 6, 'availability_60': 15, ...        1.0  Real Bed
# 4610  {'availability_30': 30, 'availability_60': 60,...        2.0  Real Bed
# 4629  {'availability_30': 27, 'availability_60': 57,...        1.5  Real Bed
# 4657  {'availability_30': 2, 'availability_60': 4, '...        2.0  Real Bed
# 4691  {'availability_30': 6, 'availability_60': 36, ...        7.0  Real Bed
# 4714  {'availability_30': 0, 'availability_60': 0, '...        2.5  Real Bed
# 4842  {'availability_30': 14, 'availability_60': 44,...        1.0  Real Bed
# 4877  {'availability_30': 30, 'availability_60': 60,...        1.5  Real Bed
# 5027  {'availability_30': 30, 'availability_60': 60,...        2.0  Real Bed
# 5050  {'availability_30': 16, 'availability_60': 19,...        1.0  Real Bed
# 5051  {'availability_30': 0, 'availability_60': 0, '...        2.0  Real Bed
# 5056  {'availability_30': 18, 'availability_60': 42,...        1.0  Real Bed
# 5114  {'availability_30': 28, 'availability_60': 58,...        1.0  Real Bed
# 5138  {'availability_30': 0, 'availability_60': 7, '...        2.0  Real Bed
# 5151  {'availability_30': 11, 'availability_60': 17,...        2.0  Real Bed
# 5270  {'availability_30': 0, 'availability_60': 0, '...        2.5  Real Bed
# 5276  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 5308  {'availability_30': 23, 'availability_60': 53,...        4.5  Real Bed
# 5367  {'availability_30': 0, 'availability_60': 0, '...        5.0  Real Bed
# 5378  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
# 5389  {'availability_30': 27, 'availability_60': 57,...        1.0  Real Bed
# 5428  {'availability_30': 14, 'availability_60': 24,...        1.0  Real Bed
# 5473  {'availability_30': 0, 'availability_60': 0, '...        4.0  Real Bed
# 5544  {'availability_30': 20, 'availability_60': 31,...        2.0  Real Bed
# 5551  {'availability_30': 0, 'availability_60': 0, '...        2.0  Real Bed
# 5554  {'availability_30': 0, 'availability_60': 0, '...        1.0  Real Bed
#
#       bedrooms  ...       property_type  \
# 100        4.0  ...               House
# 103        3.0  ...           Apartment
# 117        6.0  ...               House
# 128        1.0  ...           Apartment
# 132        3.0  ...           Apartment
# 141        1.0  ...           Apartment
# 142        2.0  ...           Apartment
# 281        3.0  ...           Apartment
# 311        4.0  ...           Apartment
# 312        4.0  ...           Apartment
# 347        3.0  ...           Apartment
# 355        4.0  ...         Condominium
# 377        1.0  ...           Apartment
# 387        3.0  ...           Apartment
# 396        1.0  ...           Apartment
# 408        3.0  ...           Apartment
# 415        5.0  ...         Condominium
# 440        2.0  ...           Apartment
# 471        2.0  ...           Apartment
# 474        1.0  ...           Apartment
# 481        3.0  ...           Apartment
# 494        2.0  ...           Apartment
# 559        2.0  ...           Apartment
# 579        2.0  ...           Apartment
# 590        0.0  ...           Apartment
# 597        2.0  ...           Apartment
# 638        3.0  ...           Apartment
# 654        1.0  ...           Apartment
# 656        3.0  ...           Apartment
# 743        3.0  ...   Bed and breakfast
# ...        ...  ...                 ...
# 4459       3.0  ...                Loft
# 4506      10.0  ...   Bed and breakfast
# 4575       1.0  ...           Apartment
# 4592       2.0  ...           Apartment
# 4600       2.0  ...           Apartment
# 4610       2.0  ...               House
# 4629       2.0  ...           Apartment
# 4657       3.0  ...           Apartment
# 4691       6.0  ...  Serviced apartment
# 4714       3.0  ...           Apartment
# 4842       3.0  ...           Apartment
# 4877       3.0  ...           Apartment
# 5027       4.0  ...           Apartment
# 5050       2.0  ...         Condominium
# 5051       2.0  ...           Apartment
# 5056       1.0  ...         Condominium
# 5114       2.0  ...           Apartment
# 5138       3.0  ...           Apartment
# 5151       3.0  ...         Condominium
# 5270       3.0  ...           Apartment
# 5276       3.0  ...           Apartment
# 5308       5.0  ...           Apartment
# 5367       5.0  ...               House
# 5378       2.0  ...           Apartment
# 5389       1.0  ...         Condominium
# 5428       1.0  ...  Serviced apartment
# 5473       6.0  ...               House
# 5544       3.0  ...           Apartment
# 5551       3.0  ...           Apartment
# 5554       1.0  ...           Apartment
#
#                                           review_scores  \
# 100                                                  {}
# 103                                                  {}
# 117                                                  {}
# 128                                                  {}
# 132   {'review_scores_accuracy': 9, 'review_scores_c...
# 141   {'review_scores_accuracy': 10, 'review_scores_...
# 142   {'review_scores_accuracy': 10, 'review_scores_...
# 281   {'review_scores_accuracy': 9, 'review_scores_c...
# 311                                                  {}
# 312                                                  {}
# 347                                                  {}
# 355                                                  {}
# 377   {'review_scores_accuracy': 9, 'review_scores_c...
# 387                                                  {}
# 396                                                  {}
# 408                                                  {}
# 415   {'review_scores_accuracy': 8, 'review_scores_c...
# 440                                                  {}
# 471                                                  {}
# 474                                                  {}
# 481                                                  {}
# 494   {'review_scores_accuracy': 10, 'review_scores_...
# 559                                                  {}
# 579   {'review_scores_accuracy': 10, 'review_scores_...
# 590                                                  {}
# 597                                                  {}
# 638                                                  {}
# 654   {'review_scores_accuracy': 10, 'review_scores_...
# 656   {'review_scores_accuracy': 10, 'review_scores_...
# 743                                                  {}
# ...                                                 ...
# 4459  {'review_scores_accuracy': 10, 'review_scores_...
# 4506  {'review_scores_accuracy': 8, 'review_scores_c...
# 4575  {'review_scores_accuracy': 10, 'review_scores_...
# 4592                                                 {}
# 4600  {'review_scores_accuracy': 10, 'review_scores_...
# 4610                                                 {}
# 4629                                                 {}
# 4657  {'review_scores_accuracy': 9, 'review_scores_c...
# 4691  {'review_scores_accuracy': 9, 'review_scores_c...
# 4714                                                 {}
# 4842  {'review_scores_accuracy': 10, 'review_scores_...
# 4877                                                 {}
# 5027                                                 {}
# 5050  {'review_scores_accuracy': 9, 'review_scores_c...
# 5051  {'review_scores_accuracy': 10, 'review_scores_...
# 5056  {'review_scores_accuracy': 9, 'review_scores_c...
# 5114                                                 {}
# 5138  {'review_scores_accuracy': 10, 'review_scores_...
# 5151  {'review_scores_accuracy': 8, 'review_scores_c...
# 5270                                                 {}
# 5276  {'review_scores_accuracy': 10, 'review_scores_...
# 5308                                                 {}
# 5367                                                 {}
# 5378  {'review_scores_accuracy': 10, 'review_scores_...
# 5389  {'review_scores_accuracy': 9, 'review_scores_c...
# 5428  {'review_scores_accuracy': 10, 'review_scores_...
# 5473                                                 {}
# 5544  {'review_scores_accuracy': 6, 'review_scores_c...
# 5551                                                 {}
# 5554                                                 {}
#
#                                                 reviews  reviews_per_month  \
# 100                                                  []                NaN
# 103                                                  []                NaN
# 117                                                  []                NaN
# 128                                                  []                NaN
# 132   [{'_id': '61277620', 'date': datetime.datetime...                NaN
# 141   [{'_id': '64686084', 'date': datetime.datetime...                NaN
# 142   [{'_id': '192194362', 'date': datetime.datetim...                NaN
# 281   [{'_id': '5528473', 'date': datetime.datetime(...                NaN
# 311                                                  []                NaN
# 312                                                  []                NaN
# 347                                                  []                NaN
# 355                                                  []                NaN
# 377   [{'_id': '24990411', 'date': datetime.datetime...                NaN
# 387                                                  []                NaN
# 396                                                  []                NaN
# 408                                                  []                NaN
# 415   [{'_id': '134699468', 'date': datetime.datetim...                NaN
# 440                                                  []                NaN
# 471                                                  []                NaN
# 474                                                  []                NaN
# 481                                                  []                NaN
# 494   [{'_id': '86183736', 'date': datetime.datetime...                NaN
# 559                                                  []                NaN
# 579   [{'_id': '94373575', 'date': datetime.datetime...                NaN
# 590                                                  []                NaN
# 597                                                  []                NaN
# 638                                                  []                NaN
# 654   [{'_id': '111051483', 'date': datetime.datetim...                NaN
# 656   [{'_id': '89293120', 'date': datetime.datetime...                NaN
# 743                                                  []                NaN
# ...                                                 ...                ...
# 4459  [{'_id': '16622590', 'date': datetime.datetime...                NaN
# 4506  [{'_id': '57003309', 'date': datetime.datetime...                NaN
# 4575  [{'_id': '21904074', 'date': datetime.datetime...                NaN
# 4592                                                 []                NaN
# 4600  [{'_id': '24302290', 'date': datetime.datetime...                NaN
# 4610                                                 []                NaN
# 4629                                                 []                NaN
# 4657  [{'_id': '23930301', 'date': datetime.datetime...                NaN
# 4691  [{'_id': '191206', 'date': datetime.datetime(2...                NaN
# 4714                                                 []                NaN
# 4842  [{'_id': '49976571', 'date': datetime.datetime...                NaN
# 4877                                                 []                NaN
# 5027                                                 []                NaN
# 5050  [{'_id': '2412981', 'date': datetime.datetime(...                NaN
# 5051  [{'_id': '41685568', 'date': datetime.datetime...                NaN
# 5056  [{'_id': '51384338', 'date': datetime.datetime...                NaN
# 5114                                                 []                NaN
# 5138  [{'_id': '44967231', 'date': datetime.datetime...                NaN
# 5151  [{'_id': '43170871', 'date': datetime.datetime...                NaN
# 5270                                                 []                NaN
# 5276  [{'_id': '139352379', 'date': datetime.datetim...                NaN
# 5308                                                 []                NaN
# 5367                                                 []                NaN
# 5378  [{'_id': '53865244', 'date': datetime.datetime...                NaN
# 5389  [{'_id': '53545883', 'date': datetime.datetime...                NaN
# 5428  [{'_id': '268787581', 'date': datetime.datetim...                NaN
# 5473                                                 []                NaN
# 5544  [{'_id': '58630763', 'date': datetime.datetime...                NaN
# 5551                                                 []                NaN
# 5554                                                 []                NaN
#
#             room_type  security_deposit  \
# 100   Entire home/apt               NaN
# 103   Entire home/apt               NaN
# 117   Entire home/apt               NaN
# 128      Private room               NaN
# 132   Entire home/apt            1500.0
# 141   Entire home/apt            5000.0
# 142   Entire home/apt               0.0
# 281   Entire home/apt            1570.0
# 311   Entire home/apt               NaN
# 312   Entire home/apt            2500.0
# 347   Entire home/apt               NaN
# 355   Entire home/apt               NaN
# 377   Entire home/apt            5000.0
# 387   Entire home/apt               NaN
# 396   Entire home/apt               NaN
# 408   Entire home/apt               NaN
# 415   Entire home/apt               NaN
# 440   Entire home/apt               NaN
# 471   Entire home/apt               NaN
# 474      Private room               NaN
# 481   Entire home/apt            5595.0
# 494   Entire home/apt            1000.0
# 559   Entire home/apt               NaN
# 579   Entire home/apt            1492.0
# 590   Entire home/apt            3730.0
# 597   Entire home/apt           13055.0
# 638   Entire home/apt            3730.0
# 654   Entire home/apt            3000.0
# 656   Entire home/apt               0.0
# 743      Private room               NaN
# ...               ...               ...
# 4459  Entire home/apt            6000.0
# 4506  Entire home/apt               NaN
# 4575  Entire home/apt               NaN
# 4592  Entire home/apt            2000.0
# 4600  Entire home/apt               NaN
# 4610  Entire home/apt           15818.0
# 4629  Entire home/apt               0.0
# 4657  Entire home/apt            3140.0
# 4691  Entire home/apt            2956.0
# 4714  Entire home/apt            1865.0
# 4842  Entire home/apt            4000.0
# 4877  Entire home/apt               NaN
# 5027  Entire home/apt               NaN
# 5050  Entire home/apt            1963.0
# 5051  Entire home/apt               NaN
# 5056     Private room               NaN
# 5114  Entire home/apt               NaN
# 5138  Entire home/apt               0.0
# 5151  Entire home/apt               NaN
# 5270  Entire home/apt            3730.0
# 5276  Entire home/apt            2000.0
# 5308  Entire home/apt            1300.0
# 5367  Entire home/apt             800.0
# 5378  Entire home/apt            1000.0
# 5389     Private room               NaN
# 5428  Entire home/apt             785.0
# 5473  Entire home/apt               NaN
# 5544  Entire home/apt               NaN
# 5551  Entire home/apt               NaN
# 5554  Entire home/apt               NaN
#
#                                                   space  \
# 100    Piscina, gramado, acomada 8 pessoas em 4 suítes.
# 103   In the heart of Ipanema, the apartment is very...
# 117   Built before the turn of the century, this ful...
# 128                                                 NaN
# 132   Its a classic central hong kong style building...
# 141                                                 NaN
# 142   We will accommodate a maximum of 5 guests incl...
# 281   FACTS - located in the heart of one of Hong Ko...
# 311                     The location, size and comfort.
# 312                                                 NaN
# 347                                                 NaN
# 355   Apartamento ventilado, com uma área de 190m2, ...
# 377   right next to the beach and nature..plus all t...
# 387                                                 NaN
# 396   O imóvel possui sala, quarto, banheiro, varand...
# 408                                                 NaN
# 415   This penthouse is located at one of the best b...
# 440   The apartment gets great light and has high ce...
# 471   Ar condicionado no quarto e sala. 2 vagas de g...
# 474                                                 NaN
# 481                                                 NaN
# 494   Our apartment offers 2 large bedrooms both wit...
# 559                                                 NaN
# 579                                                 NaN
# 590                                                 NaN
# 597                                                 NaN
# 638                                                 NaN
# 654   Beautiful views over Hollywood Park - balcony ...
# 656   LUXURY 3BR Bathtub 1min MTR 4-9ppl NEWLY (JULY...
# 743   Greatly located in the Old City of the Istanbu...
# ...                                                 ...
# 4459  Loft spacieux de 3 chambres, ce 3 chambres est...
# 4506                                                NaN
# 4575  I rent this house so that i can provide more s...
# 4592  200 metros da praia, lugar agradável e com ace...
# 4600  Very comfortable and quiet Gym, swimming pool,...
# 4610  Excellent location, as much as comfortable tra...
# 4629  Is very near the beach, four blocks. Clean, wi...
# 4657  We are on Hennessy Road we're just 5 minute wa...
# 4691  ••• WHY AND HOW WE DIFFER ••• Our guest loves ...
# 4714  Situated along the legendary Copacabana Beach,...
# 4842  located within walking distance of causeway ba...
# 4877  Only 300 metres from the lively Taksim Square ...
# 5027  A localização sem dúvida é o ponto mais forte ...
# 5050  This 2 bedroom apartment is just located at 30...
# 5051                                                NaN
# 5056  We opened in 1987 and we are on the 21 st floo...
# 5114                                                NaN
# 5138  You can use our entire apartment, including 3 ...
# 5151  There are 3 rooms 2 with double bed 1 with 1 d...
# 5270         Family apartment for Olympic Games rental.
# 5276                               Room size: 75 meters
# 5308  Great location , sensational apartment in Copa...
# 5367  5-Story House located in Copacabana.  ONLY 5 S...
# 5378  The luxurious & spacious apartment is situated...
# 5389  We opened in 1987 and we are on the 21 st floo...
# 5428  What u would like about our building is it is ...
# 5473  Nossa casa é extremamente arejada e iluminada....
# 5544                                                NaN
# 5551                                                NaN
# 5554                                                NaN
#
#                                                 summary  \
# 100   Casa em São Conrado, com vista para a floresta...
# 103   Fantastic apt for 6 people a block from the be...
# 117   A beautiful colonial mansion for office or res...
# 128                                  我的房源適合情侶和獨自旅行的冒險家｡
# 132   Welcome to stay in my 3bed apartment. Its a ra...
# 141   We live in a beautiful and spacious one bedroo...
# 142   Bright and spacious two bedroom apartment loca...
# 281   Location is OUTSTANDING as MTR Causeway BAY is...
# 311   Our apt. is comfortable, spacious and located ...
# 312   Nossa cobertura é muito aconchegante, moderna ...
# 347   Com 2 vagas de garagem ,Porteiro 24 horas, TV ...
# 355   Apto amplo, confortável, em frente à praia da ...
# 377   A charming,funky cool 1 bdrm flat in older wal...
# 387   111m2. Apto luxo impecável. Aluguel para olimp...
# 396   Excelente flat próximo à praia de ipanema, tod...
# 408   Three bedroom apartment renovated in 2015, in ...
# 415   This explendid penthouse has 4.400 ft2, with 5...
# 440   This is a large walk-up with high ceilings, lo...
# 471   Nosso apartamento é super aconchegante, acomod...
# 474   Room available with 1 super nice French roomma...
# 481   Meu espaço é perto de Próximo ao shopping, pra...
# 494   Great apartment centrally located within 5 min...
# 559   Meu espaço é perto de shopping Recreio, há 500...
# 579   My space is next to the Olympic village (about...
# 590   Meu espaço é perto de atividades para famílias...
# 597   Meu espaço é perto de Em frente ao Rio Olympic...
# 638                  Ground Zero for the Olympic Games.
# 654   My place is good for couples, solo adventurers...
# 656   NEWLY (JULY 2016) and LUXURY Bathtub apartment...
# 743   It is Iocated in the old part of Istanbul, 400...
# ...                                                 ...
# 4459  Loft spacieux sur un étage, lumineux, dans bât...
# 4506  Welcome To Sultanahmet Star Holiday Hotel! Sta...
# 4575  My house is very cosy safe and close to main a...
# 4592  2 Quartos arejado, com vista da praia, ar cond...
# 4600  Comfortable 2 rooms (1 single bed + 1 double b...
# 4610  2 bedrooms, 1 dining room, 1 TV room, excelent...
# 4629  A nice place to stay while your are visiting R...
# 4657  New Decoration 3-bedrooms apartment with cozy ...
# 4691  Sunny terrace with side ocean view, 6 ensuite ...
# 4714  Brazilian style, mixed with classic European e...
# 4842  Provided weekly cleaning service, new towels, ...
# 4877  Apart otelimiz istanbulun göbeği taksim meydan...
# 5027  Excelente apto. 4 quartos em copacabana há 2 q...
# 5050  This 2 bedroom apartment is just located at 30...
# 5051  Conveniently located by the escalator in moder...
# 5056  We are licensed guest house, opened in 1987. A...
# 5114  Best location you can find heart of the city E...
# 5138  Perched in the Mid Levels, 10 minutes’ walk fr...
# 5151  This is a 3 bedroom apartment with 2 bathroom ...
# 5270  Design 3 bedroom apartment, large rooms, kitch...
# 5276  The three-Bedroom Deluxe offers a well-designe...
# 5308                       Apartment for up to 6 people
# 5367  A 5-story house, where the owners live in 2 ap...
# 5378  Entire apartment, 65 ㎡, very spacious, complet...
# 5389  We are licensed guest house, opened in 1987. A...
# 5428  Cosy homestay at heart of HK Island! All you n...
# 5473  Casa magnífica no bairro Jardim Botânico com v...
# 5544                                      交通方便,购物旅遊好去處_
# 5551  Big apartment (3 bedrooms + 2 bathrooms + 40 m...
# 5554  Located at the heart of Kowloon, our unit is s...
#
#                                                 transit weekly_price
# 100                                                 NaN          NaN
# 103   Close to the subw Bus station in front of the ...          NaN
# 117                                                 NaN          NaN
# 128                                                 NaN          NaN
# 132                                                 NaN          NaN
# 141   The area is well served by minibuses, City Bus...          NaN
# 142   The Airport Express direct from the airport ar...       7500.0
# 281   HOW TO GET TO CAUSEWAY BAY: By Public transpor...          NaN
# 311   Close to the subway and easily accessible by bus.          NaN
# 312                                                 NaN          NaN
# 347                                                 NaN          NaN
# 355   Fácil acesso transportes públicos,  táxis em d...          NaN
# 377   Yes, right at below doorstep are the major bus...       6000.0
# 387                                                 NaN          NaN
# 396   Imóvel com estacionamento no local, além de se...          NaN
# 408                                                 NaN          NaN
# 415           Subway station (15 min. walking distance)          NaN
# 440   This is a very central location with great acc...          NaN
# 471   Sim, ônibus com destino ao centro da cidade e ...          NaN
# 474                                                 NaN          NaN
# 481                                                 NaN          NaN
# 494   Getting around Hong Kong from our flat is very...          NaN
# 559                                                 NaN          NaN
# 579                                                 NaN          NaN
# 590                                                 NaN          NaN
# 597                                                 NaN          NaN
# 638                                                 NaN          NaN
# 654   Very easy to get taxis outside the flat and th...          NaN
# 656   There is convenient public transit. From the a...          NaN
# 743   Blue Mosque  Hagia Sophia  Little Hagia Sophia...          NaN
# ...                                                 ...          ...
# 4459                                                NaN       4850.0
# 4506                                                NaN          NaN
# 4575  Yes my house is very close to the Sishane Metr...        953.0
# 4592                               Metrô, ônibus e táxi          NaN
# 4600  Bus stop, taxi stand in the building area, MTR...          NaN
# 4610             very easy accesable point for İstanbul      18455.0
# 4629  all means of transportantion, like buses, car,...          NaN
# 4657  There is convenient public transit. From the a...      10833.0
# 4691  The beach is a few steps away. Bus stop and ta...          NaN
# 4714                                                NaN          NaN
# 4842  Airport 25mins to central then 8mins to Tin Ha...          NaN
# 4877  Salimbey apartments is in taksim, centre of is...          NaN
# 5027  a estação de metro siqueira campos se localiza...          NaN
# 5050                                                NaN          NaN
# 5051                                                NaN       7700.0
# 5056  Tourist spot in/around Mong Kok: * Sai Yeung C...          NaN
# 5114                                                NaN          NaN
# 5138  Getting around has never been easier! There ar...       1600.0
# 5151                                                NaN          NaN
# 5270         2 car parking, walking distance to subway.          NaN
# 5276  AirportTo apartment: 25mins to central then 8m...          NaN
# 5308                                                NaN          NaN
# 5367  Subway, buses and taxis 24h 5 minutes from our...          NaN
# 5378                                                NaN          NaN
# 5389  Tourist spot in/around Mong Kok: * Sai Yeung C...          NaN
# 5428  There are bus A11 from HK Airport direct to CW...          NaN
# 5473                                                NaN          NaN
# 5544                                                NaN       4888.0
# 5551                                                NaN          NaN
# 5554                                                NaN          NaN
#
# [189 rows x 43 columns]

# %%
data[data['price']>1000]['listing_url']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-0b2bb639062d> in <module>
# ----> 1 data, metadata = get_ipython().display_formatter.format(data[data['price']>1000]['listing_url'])
#       2 with open('table.html', 'w') as f:
#       3     f.write(data[data['price']>1000]['listing_url'])  # Assuming the object has an HTML representation
#       4
#       5 #data[data['price']>1000]['listing_url']
#
# KeyError: 'price'

# %% [markdown]
# It looks like these are mostly in the Ipanema area of Rio de Janiero, an expensive area, and in Hong Kong (no suprise there)

# %% [markdown]
# ## Missing values

# %%
# Fill NaN for cleaning_fee to 0
data['cleaning_fee'].fillna(0, inplace=True)

# %%
data['security_deposit'].fillna(0, inplace=True)

# %%
data['review_scores'].fillna('None', inplace=True)

# %%
data['access'].fillna('None', inplace=True)

# %% [markdown]
# The 'bathrooms','bed_type','bedrooms','beds' we can just fill the missing values with the mode

# %%
cols = ['bathrooms','bed_type','bedrooms','beds']
data[cols] = data[cols].fillna(data[cols].mode().iloc[0])

# %%
data['description'] = data['description'].fillna('None')

# %% [markdown]
# ### Geography

# %%
def get_city(x):
    result = re.search("'market':(.*), 'country'", x)
    return result.group(1)

def get_state(x):
    return x.split(",")[1]

def get_country(x):
    result = re.search("'country':(.*), 'country_code'", x)
    return result.group(1)

def get_suburb(x):
    result = re.search("'suburb':(.*), 'government_area'", x)
    return result.group(1)

def get_government_area(x):
    result = re.search("'government_area':(.*), 'market'", x)
    return result.group(1)

# %%
data['state'] = data['address'].apply(get_state)

# %%
data['city'] = data['address'].apply(get_city)

# %%
data['country'] = data['address'].apply(get_country)

# %%
data['suburb'] = data['address'].apply(get_suburb)

# %%
data['government_area'] = data['address'].apply(get_government_area)

# %% [markdown]
# ### Country and Prices

# %% [markdown]
# Airbnb uses a practice called Dynamic Currency Conversion to show your price to you in e.g. USD.

# %%
# what is the average price per night per country
means = data.groupby('country')['price'].mean()

# %%
means
# Out:
# country
#  'Australia'        197.806557
#  'Brazil'           449.613065
#  'Canada'           100.117103
#  'China'            405.368421
#  'Hong Kong'        688.683502
#  'Portugal'          69.181982
#  'Spain'            100.826224
#  'Turkey'           270.614916
#  'United States'    185.769231
# Name: price, dtype: float64

# %%
# How many listings per country
sns.countplot(data['country'])

# %%
fig_dims = (12, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.violinplot(x="country", y="price", ax=ax, data=data,palette='rainbow')

# %% [markdown]
# ### Reviews

# %%
def get_review_scores_rating(x):
    if x != "{}":
        return int(x.split(",")[-1].split(":")[1][-4:-1])
    else:
        return 0

# %%
data['review_scores_rating'] = data['review_scores'].apply(get_review_scores_rating)

# %%
data['review_scores_rating'].fillna(data['review_scores_rating'].mean(), inplace=True)

# %%
sns.distplot(data['review_scores_rating'], bins=30)

# %% [markdown]
# ## Reviews

# %% [markdown]
# ### Does more reviews trend with higher price

# %%
print(data['reviews'].iloc[0])

# %%
data['reviews_length'] = data['reviews'].apply(len)

# %%
sns.jointplot(data=data, x='reviews_length', y='price', kind='scatter')

# %%
#data[data['reviews_length'] > 100000]['reviews'].loc[149]

# %% [markdown]
# Wow. Some of these reviews are enough for a book! However, the number of reviews a listing has no correlation with price.  Actually is seems that most of the most expensive properties

# %%
data.drop('reviews_length',axis=1, inplace=True)

# %% [markdown]
# Lets just make a feature that says if there was a review or not

# %%
data['has_reviews'] = data['reviews'].apply(lambda x: 0 if x == '[]' else 1)

# %%
plt.figure(figsize=(10,6))
data[data['has_reviews']==1]['price'].hist(alpha=0.5,color='blue',
                                              bins=50,label='has_reviews=1')
data[data['has_reviews']==0]['price'].hist(alpha=0.5,color='red',
                                              bins=50,label='has_reviews=0')
plt.legend()
plt.xlabel('Price')

# %% [markdown]
# Those listings that have reivews have a slightly higher price distribution than those without.  But those with the highest price listings do not have reviews. Interesting

# %%
def get_comments(x):
    comments = []
    if x != '[]':
        entries = x.split("}, {")
        for entry in entries:
            pattern = "'comments':(.*)"
            try:
                comments = [(re.search(pattern, entry).group(1)).replace("\\r\\n", "") for entry in entries]
            except:
                print("oops")
    else:
        x = []
    return comments

# %%
data['comments'] = data['reviews'].apply(get_comments)

# %%
data['comments'][0]

# %%
# Remove the '/' to clean it up
def remove_slash(x):
    for item in x:
        item.replace('/', '')
        return x

# %%
data['comments'] = data['comments'].apply(remove_slash)

# %%
data.drop('reviews', axis=1, inplace=True)

# %% [markdown]
# ## Amenities

# %%
import json
import ast
import sys, json

# turn this string objct to list with json.loads
def get_amenities(x):
    struct = {}
    try:
        try: #try parsing to dict
            dataform = str(x).strip("'<>() ").replace('\'', '\"')
            struct = json.loads(dataform)
            return struct
        except:
            print(repr(resonse_json))
    except:
        print("fine")

# %%
data['amenities_list'] = data['amenities'].apply(get_amenities)

# %%
data.drop('amenities', axis=1, inplace=True)

# %%
def jsonify(x):
    if x != {}:
        return json.loads(x)
    else:
        return "{}"

# %%
#def get_eval(x):
#    return eval(x)

# %% [markdown]
# Create feature, 'has_notes' that is binary either 1 or 0 if there are notes or not from the owner.

# %%
data['has_notes'] = data['notes'].apply(lambda x: 1 if type(x) == str else 0)

# %%
data.drop('notes', axis=1, inplace=True)

# %% [markdown]
# ### Create length features that create a numeric value for the length of texts columns like notes, reviews, description

# %%
data['access_length'] = data['access'].apply(len)

# %%
#plot access_length against price
sns.jointplot(data=data, x='access_length', y='price', kind='scatter')

# %%
data.drop('weekly_price', axis=1, inplace=True)

# %%
#data.drop("images", axis=1, inplace=True)

# %%
data[data['price']>1000]

# %% [markdown]
# # Removing worthless columns

# %%
data.info()

# %% [markdown]
# Lets get a better look at these columns in the middle, pandas df view wont show up those

# %%
data[data['reviews_per_month']!= 'Nan'].iloc[:,15:30]

# %% [markdown]
# We can drop id, first_review, host, last_review, last_scraped, and listing url becuase they are really just sort of index values that dont hold much value as to the actual place.  Perhaps there is a really bad host to watch out for but this really just adds noise to our model.  'name' and 'neighborhood_overview' are subjectve comments that are biased to the point of view of the host so they should be dropped.  We can however change them to a binary as to whether they exist or not and that will take care of the missing values.

# %%
data.drop(['_id','first_review', 'host','last_review','last_scraped','listing_url'], axis=1, inplace=True)

# %%
data['has_name'] = data['name'].apply(lambda x: 1 if type(x) == str else 0)

# %%
data['has_neighborhood_overview']= data['neighborhood_overview'].apply(lambda x: 1 if type(x) == str else 0)

# %% [markdown]
# Monthly price has too many nulls

# %%
type(data['neighborhood_overview'][0])

# %%
data.drop('monthly_price', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,6))
data[data['has_neighborhood_overview']==1]['price'].hist(alpha=0.5,color='blue',
                                              bins=50,label='has_neighborhood_overview=1')
data[data['has_neighborhood_overview']==0]['price'].hist(alpha=0.5,color='red',
                                              bins=50,label='has_neighborhood_overview=0')
plt.legend()
plt.xlabel('Price')
plt.ylabel('Count')

# %%
data['description'] = data['description'].fillna('None')

# %% [markdown]
# ## Availability

# %%
def get_30(x):
    x = int(x[20:21])
    return x

# %%
data['availability_30'] = data['availability'].apply(get_30)

# %%
type(data['availability_30'][0])

# %%
def get_60(x):
    result = re.search("'availability_60':(.*), 'availability_90'", x)
    return int(result.group(1))

# %%
data['availability_60'] = data['availability'].apply(get_60)

# %%
def get_90(x):
    result = re.search("'availability_90':(.*), 'availability_365'", x)
    return int(result.group(1))

# %%
data['availability_90'] = data['availability'].apply(get_90)

# %%
data['availability'][0]

# %%
def get_365(x):
    result = re.search("'availability_365':(.*)}", x)
    return int(result.group(1))

# %%
data['availability_365'] = data['availability'].apply(get_365)

# %%
data.drop('availability', axis=1, inplace=True)

# %%
data.info()

# %%
data.drop('name', axis=1, inplace=True )

# %%
data.drop('reviews_per_month', axis=1, inplace=True)

# %%
data['house_rules']

# %%
data.to_csv(r"C:\Users\Ben\Documents\Fairbnb\data\clean_data.csv")
